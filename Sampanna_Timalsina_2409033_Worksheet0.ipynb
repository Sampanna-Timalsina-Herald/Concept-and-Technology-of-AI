# %% [markdown]
# # Worksheet-0
# # Sampanna Timalsina

# %% [markdown]
# Python Version Check

# %%
import sys
if sys.version_info.major ==3 and sys.version_info.minor>=6:
    print("Hello World!")
    print(f"Python version:{sys.version}")
else:
    print("Please use Python 3.6 or higher")
# Out:
# Hello World!
# Python version:3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
## Program to create lists and sort temperatures into them

temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1,
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7,
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8,
16.6, 12.5]

#Three empty lists to store the Variable of different weather conditions
cold=[]
mild=[]
comfortable=[]

for temperature in temperatures:
    if(temperature < 10):
        Cold.append(temperature)
    elif( 10<= temperature <15):
        Mild.append(temperature)
    elif(15 < temperature < 20 ):
        Comfortable.append(temperature)
    else:
        print("Invalid Temperature")



#Printing The result For Task 1
print(f"The Cold Temperatures are:{cold}")
print(f"The Mild Temperatures are:{mild}")
print(f"The Comfortable Temperatures are:{comfortable}")


#Printing The result for Task 2
print(f"It was {len(mild)} times Mild")
print(f"It was {len(cold)} times Cold")
print(f"It was {len(comfortable)} times Comfortable")
# Out:
# The Cold Temperatures are:[8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# The Mild Temperatures are:[14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# The Comfortable Temperatures are:[17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# It was 16 times Mild
# It was 16 times Cold
# It was 16 times Comfortable

# %%
#Task 3
#A program to convert the given temperature in Celsius to Fahrenheit 
#Formula Fahrenheit=(Celsius * 9/5)+32

#A new List to store the temperature in Fahrenheit
fahrenheit = []
for temperature in temperatures:
    #Inserting the converted temperature to the empty list after formatting it to 2 decimal place
    fahrenheit.append(round((temperature * 9/5)+32,2))
print(f"The temperatures in fahrenheit are:{fahrenheit}")
# Out:
# The temperatures in fahrenheit are:[46.76, 63.32, 57.38, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.96, 55.94, 47.12, 62.06, 57.2, 49.1, 64.94, 56.12, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.52, 54.86, 48.02, 64.76, 55.58, 46.04, 61.88, 54.5]

# %%
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1,
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7,
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8,
16.6, 12.5]
Night=[]
Day=[]
Evening=[]
for i in range(0,len(temperatures)-1,3):
    Night.append(temperatures[i])
    Day.append(temperatures[i+2])
    Evening.append(temperatures[i+1])
print(Day)
print(Night)
print(Evening)

#Calculating the average day-time temperature
average_day_time=sum(Day)/len(Day)
print(f"The average day-time temperature is:{round(average_day_time,2)}\u00B0C")
# Out:
# [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# The average day-time temperature is:13.41°C

# %%
import matplotlib.pyplot as plt
day_temperatures=Day
no_of_days=[x for x in range(1,17,1)]
plt.plot(no_of_days,day_temperatures)
plt.xlabel("NUMBER OF DAYS")
plt.ylabel("DAY TEMPERATURES")
plt.show()

# %%
#RECURSION
#1
def sum_nested_list(nested_list):
"""
 Calculate the sum of all numbers in a nested list.
 This function takes a list that may contain integers and other nested lists.
 It recursively traverses the list and sums all the integers, no matter how deeply
 nested they are.
 Args:
 nested_list (list): A list that may contain integers or other lists of integers.
 Returns:
        int :The sum of integers of the list
"""
    total=0
    for element in nested_list:
        if isinstance(element,list):
            total += sum_nested_list(element)
        else:
            total += element
    return total
print(f"The sum of the integers of the nested list is:{sum_nested_list([1,[2,3,4],5])}")
# Out:
# The sum of the integers of the nested list is:15

# %%
#2
def generate_permutations(s):
    """
    A function to compute all the unique permutations of a string.
    This function accepts a string and generates all its possible unique permutations.
    It also utilizes a helper function, `permute`, which accepts 4 parameters
    to generate the permutations.
    """
    def permute(result, s, end, start):
        if start == end:
            result.append("".join(s))
        else:
            seen = set()
            for i in range(start, end):
                if s[i] in seen:
                    continue
                seen.add(s[i])
                s[start], s[i] = s[i], s[start]
                permute(result, s, end, start + 1)
                s[start], s[i] = s[i], s[start]

    # If all characters are the same, return the input string as the only permutation
    if all(c == s[0] for c in s):
        return ["".join(s)]

    result = []
    permute(result, list(s), len(s), 0)
    return result

# Test the function
print(generate_permutations("ABC"))
# Out:
# ['ABC', 'ACB', 'BAC', 'BCA', 'CBA', 'CAB']

# %%
def calculate_directory_size(directory, exists=None):
    """
    A function to determine the size of a directory using recursion. 
    Arguments:
        directory: A dictionary with file names as keys and the space they occupy as values.
    Returns:
        int: The total size of the directory.
    """
    if exists is None:
        exists = set()
    
    total_space = 0
    
    for item, value in directory.items():
        if isinstance(value, dict):
            # Check if this subdirectory has already been visited
            if id(value) in exists:
                continue
            exists.add(id(value))
            # Recursive call for the subdirectory
            total_space += calculate_directory_size(value, exists)
        else:
            total_space += value
    
    return total_space

# Example directory structure
directory = {
    "file1.txt": 500,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 800,
        "file4.txt": 200
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 300
        },
        "file6.txt": 200
    }
}

# Calculate and print the size of the directory
print(f"The size of the directory is: {calculate_directory_size(directory)} KB")
# Out:
# The size of the directory is: 2300 KB

# %%
#Task 1 Dynamic Programming Coin Change Problem:
    #making a list full of infinite value to get the minimum value with ease
    dp = [float('inf')]*(amount+1)
    dp[0]=0
    for coin in coins:
        for i in range(coin,amount+1):
            dp[i]=min(dp[i],dp[i-coin]+1)
    return dp[10] if dp[10] != float('inf') else -1 
coins=[1,2,5]
amount=11
print(f"The minimum number of coins to make the given amount is:{min_coins(coins,amount)}")
# Out:
# The minimum number of coins to make the given amount is:2

# %%
#Task 2 Dynamic Programming LongestCommonSubsequence(LCS):
def longest_common_subsequence(s1, s2):
"""
A function to find the length of the longest common subsequence. This function uses dynamic 
programming to compare the strings and determine the longest common subsequence.
Arguments:
    s1 (string): The first string to calculate the longest common subsequence.
    s2 (string): The second string to compare and find the longest common subsequence.
Returns:
    int: An integer representing the length of the longest common subsequence.
"""

    if len(s1)>len(s2):
        dp=[[0]*(len(s2)+1) for _ in range(len(s1)+1)]
    elif len(s1)<len(s2):
        dp=[[0]*(len(s1)+1) for _ in range(len(s2)+1)]
    for i in range(len(s1)-1,-1,-1):
       for j in range(len(s2)-1,-1,-1):
           if(s1[i] == s2[j]):
               dp[i][j]=1 + dp[i+1][j+1]
           else:
               dp[i][j]=max(dp[i][j+1],dp[i+1][j])
    return dp[0][0]
print(f"The longest common subsequence is:{longest_common_subsequence('abcde','ace')}")
# Out:
# The total value of items that can be carried:9

# %%
#Task 3 Dynamic Programming Knapsack Problem:
def knapsack(weights,values,capacity):
"""
A function to determine the maximum value achievable within the given capacity.
Arguments:
    weights: A list of weights associated with the objects.
    values:  A list of values corresponding to the objects.
    capacity: An integer representing the maximum weight that can be stored.
Returns:
    int: The maximum value that can be achieved within the specified capacity.
"""
    dp=[[0]*(capacity+1) for _ in range(len(weights))]
    for i in range(len(weights)):
        for j in range(capacity+1):
            if weights[i] <= j:
                #storing the values according to the weights class and profit
                dp[i][j] = max(values[i]+dp[i-1][j-weights[i]],dp[i-1][j])
            else:
                dp[i][j] = dp[i-1][j]
    return(dp[len(weights)-1][capacity])
weights=[1,3,4,5]
values=[1,4,5,7]
capacity=7
print(f"The total value of items that can be carried:{knapsack(weights,values,capacity)}")
# Out:
# The total value of items that can be carried:9
